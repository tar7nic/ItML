# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn import linear_model

data_path = "C:\\Users\\Asus\\OneDrive\\Documents\\Tarun docs\\mali.xlsx"
df = pd.read_excel(data_path)
df.head(37)
# Out:
#            STATE NAME  State Financial Year  Total Funds Available  \
# 0      Andhra Pradesh    1.0        2013-14              5344.7931
# 1   Arunachal Pradesh    2.0        2013-14               151.6459
# 2               Assam    3.0        2013-14               770.8764
# 3               Bihar    4.0        2013-14              2250.2170
# 4        Chhattisgarh    5.0        2013-14              2199.6087
# 5                 Goa    6.0        2013-14                 6.6274
# 6             Gujarat    7.0        2013-14               478.0272
# 7             Haryana    8.0        2013-14               440.7851
# 8    Himachal Pradesh    9.0        2013-14               596.8422
# 9           Jharkhand   10.0        2013-14               987.9074
# 10          Karnataka   11.0        2013-14              2044.8632
# 11             Kerala   12.0        2013-14              1320.9619
# 12     Madhya Pradesh   13.0        2013-14              2453.4945
# ...

# %%
plt.scatter(df.head(37)['State'], df.head(37)['EFU'], color='red', marker='+')

plt.plot(df.head(37)['State'], df.head(37)['EFU'], color='green')

plt.xlabel('State')
plt.ylabel('Extent of Fund Utilisation')
plt.title('Financial Year 2013-14')

plt.show()
